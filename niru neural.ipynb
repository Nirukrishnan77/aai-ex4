# %% [markdown]
# <a href="https://colab.research.google.com/github/Nirukrishnan77/aai-ex4/blob/main/niru%20neural.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets sentencepiece sacrebleu torch


from datasets import load_dataset
from transformers import MarianMTModel, MarianTokenizer
import torch

dataset = load_dataset("opus100", "en-fr")

print("Sample data from training set:")
print(dataset['train'][0])  # Show one example

model_name = "Helsinki-NLP/opus-mt-en-fr"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)


def translate(texts, model, tokenizer):

    inputs = tokenizer(texts, return_tensors="pt", padding=True, truncation=True)


    translated_tokens = model.generate(**inputs)


    translations = [tokenizer.decode(t, skip_special_tokens=True) for t in translated_tokens]
    return translations


english_sentences = [
    "Hello, how are you?",
    "The weather is nice today.",
    "I am learning neural machine translation."
]

french_translations = translate(english_sentences, model, tokenizer)

for en, fr in zip(english_sentences, french_translations):
    print(f"EN: {en}")
    print(f"FR: {fr}")
    print("-" * 40)


from sacrebleu import corpus_bleu


references = [["Bonjour, comment ça va?",
               "Il fait beau aujourd'hui.",
               "J'apprends la traduction automatique neuronale."]]

bleu = corpus_bleu(french_translations, references)
print("BLEU score:", bleu.score)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 1.8 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# en-fr/test-00000-of-00001.parquet:   0%|          | 0.00/327k [00:00<?, ?B/s]
# en-fr/train-00000-of-00001.parquet:   0%|          | 0.00/142M [00:00<?, ?B/s]
# ...

# %%
# !pip install transformers datasets sentencepiece sacrebleu torch

# %%
from datasets import load_dataset
from transformers import MarianMTModel, MarianTokenizer
import torch
dataset = load_dataset("opus100", "en-fr")
print("Sample data from training set:")
print(dataset['train'][0])
model_name = "Helsinki-NLP/opus-mt-en-fr"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)
def translate(texts, model, tokenizer):
    inputs = tokenizer(texts, return_tensors="pt", padding=True, truncation=True)
    translated_tokens = model.generate(**inputs)
    translations = [tokenizer.decode(t, skip_special_tokens=True) for t in translated_tokens]
    return translations
english_sentences = [
    "Hello, how are you?",
    "The weather is nice today.",
    "I am learning neural machine translation."
]
french_translations = translate(english_sentences, model, tokenizer)
for en, fr in zip(english_sentences, french_translations):
    print(f"EN: {en}")
    print(f"FR: {fr}")
    print("-" * 40)

from sacrebleu import corpus_bleu
references = [["Bonjour, comment ça va?",
               "Il fait beau aujourd'hui.",
               "J'apprends la traduction automatique neuronale."]]

bleu = corpus_bleu(french_translations, references)
print("BLEU score:", bleu.score)
# Out:
# Sample data from training set:
# {'translation': {'en': 'The time now is 05:08 .', 'fr': 'The time now is 05:05 .'}}
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# EN: Hello, how are you?
# FR: Bonjour, comment allez-vous ?
# ----------------------------------------
# EN: The weather is nice today.
# FR: Le temps est beau aujourd'hui.
# ----------------------------------------
# ...
